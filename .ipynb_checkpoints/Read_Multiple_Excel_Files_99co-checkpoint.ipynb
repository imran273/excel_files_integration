# %% [markdown]
# # Import Package yg di butuhkan

# %%
import pandas as pd
import numpy as np
import sqlalchemy
import glob

# %% [markdown]
# ## Disini kita akan mencoba membaca file excel dengan 2 cara
# ## Membaca Per satuan file dan membaca seluruh file dalam satu folder

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\Documents\\Data Science Class\\Day 1'

# %% [markdown]
# # Membaca File excel per satuan file

# %%
df1 = pd.read_excel('C:\\Users\\ASUS\\Documents\\Data Science Class\\Day 1\\data\\99rumah di jual\\99.co_Serpong_Jual-(Crawl-Run)---2019-02-24T140546Z.xlsx')

# %%
df1.shape
# Out:
# (8, 28)

# %%
df2 = pd.read_excel('C:\\Users\\ASUS\\Documents\\Data Science Class\\Day 1\\data\\99rumah di jual\\99.co_Serpong_Jual-(Crawl-Run)---2019-02-24T140615Z.xlsx')

# %%
df2.shape
# Out:
# (8, 28)

# %% [markdown]
# # Membuat df1 dan df2 dalam satu data frame

# %%
df3= pd.concat([df1, df2], ignore_index=True, sort=False)

# %%
df3.shape
# Out:
# (16, 28)

# %%
df4 = pd.concat([df1, df2], axis=1, join='inner')

# %%
df4.head(2)
# Out:
#                                                  url  \
# 0  https://www.99.co/id/jual/rumah/tangerang%20se...
# 1  https://www.99.co/id/jual/rumah/tangerang%20se...
#
#                                           Urban Indo  \
# 0  https://picture.urbanindo.com/listing/93940849...
# 1  https://picture.urbanindo.com/listing/20983913...
#
#                                       Urban Indo_alt  Property  \
# 0         Rp4mily Rumah Dijual; Rp4mily Rumah Dijual         2
# 1  Rp1,73mily Rumah Dijual; Rp1,73mily Rumah Diju...         3
#
#                                  Long Title  \
# 0              Dijual Rumah di Castilla BSD
# 1  Hunian Asri dan Minimalis untuk Keluarga
#
#                                      Long Title_link        Search Card  \
# 0  https://www.99.co/id/properti/rumah-dijual-4mi...  Jl. Letnan Sutopo
# 1  https://www.99.co/id/properti/rumah-dijual-1-7...            serpong
#
#    Bedrooms  Bathrooms Land Size  ...      Agent Inf Oh 5  \
# ...

# %% [markdown]
# # Membaca file Excel di seluruh folder

# %%
all_data = []
for f in glob.glob("data/99rumah di jual/*.xlsx"):
    all_data.append(pd.read_excel(f))

# %%
df = pd.concat(all_data, ignore_index=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.99.co/id/jual/rumah/tangerang%20se...
# 1  https://www.99.co/id/jual/rumah/tangerang%20se...
# 2  https://www.99.co/id/jual/rumah/tangerang%20se...
# 3  https://www.99.co/id/jual/rumah/tangerang%20se...
# 4  https://www.99.co/id/jual/rumah/tangerang%20se...
#
#                                           Urban Indo  \
# 0  https://picture.urbanindo.com/listing/93940849...
# 1  https://picture.urbanindo.com/listing/20983913...
# 2  https://picture.urbanindo.com/listing/35298993...
# 3  https://picture.urbanindo.com/listing/61333087...
# 4  https://picture.urbanindo.com/listing/35211335...
#
#                                       Urban Indo_alt  Property  \
# 0         Rp4mily Rumah Dijual; Rp4mily Rumah Dijual         2
# 1  Rp1,73mily Rumah Dijual; Rp1,73mily Rumah Diju...         3
# 2  Rp1,99mily Rumah Dijual; Rp1,99mily Rumah Diju...         3
# 3  Rp2,36mily Rumah Dijual; Rp2,36mily Rumah Diju...         7
# ...

# %%
df.shape
# Out:
# (259, 28)

# %% [markdown]
# # Memdelete konten Nan

# %%
 df.dropna(how='all')
# Out:
#                                                    url  \
# 0    https://www.99.co/id/jual/rumah/tangerang%20se...
# 1    https://www.99.co/id/jual/rumah/tangerang%20se...
# 2    https://www.99.co/id/jual/rumah/tangerang%20se...
# 3    https://www.99.co/id/jual/rumah/tangerang%20se...
# 4    https://www.99.co/id/jual/rumah/tangerang%20se...
# ..                                                 ...
# 254  https://www.99.co/id/jual/rumah/tangerang%20se...
# 255  https://www.99.co/id/jual/rumah/tangerang%20se...
# 256  https://www.99.co/id/jual/rumah/tangerang%20se...
# 257  https://www.99.co/id/jual/rumah/tangerang%20se...
# 258  https://www.99.co/id/jual/rumah/tangerang%20se...
#
#                                             Urban Indo  \
# 0    https://picture.urbanindo.com/listing/93940849...
# 1    https://picture.urbanindo.com/listing/20983913...
# 2    https://picture.urbanindo.com/listing/35298993...
# 3    https://picture.urbanindo.com/listing/61333087...
# ...

# %%
df.shape
# Out:
# (259, 28)

# %%
df = df[['Long Title', 'Bedrooms', 'Bathrooms', 'Land Size', 'Building Size', 'Untukdijual', 'Ang Suran', 'Agent Infobox Image_alt']]
df.columns = ['Alamat', 'Jumlah Kamar ', 'Jumlah Km Mandi', 'Lt', 'Lb', 'Harga', 'Cicilan', 'Nama Agen']

# %%
df.head()
# Out:
#                                               Alamat  Jumlah Kamar   \
# 0                       Dijual Rumah di Castilla BSD              3
# 1           Hunian Asri dan Minimalis untuk Keluarga              3
# 2  Rumah 1 lantai lokasi strategis, Anggrek Loka BSD              3
# 3  Rumah BARU Siap huni Bisa KPR Dekat Tol Jorr. ...              3
# 4  Green Cove BSD - Rumah Modern Tropis Renovasi ...              4
#
#    Jumlah Km Mandi     Lt     Lb       Harga       Cicilan           Nama Agen
# 0                3  180m²  270m²     Rp4mily  Rp33,4jt/bln       Vivi Agustina
# 1                2  144m²  140m²  Rp1,73mily  Rp14,5jt/bln  Muhammad Irzamsyah
# 2                2  180m²  140m²  Rp1,99mily  Rp16,6jt/bln          Syela Tjoa
# 3                2  221m²  125m²  Rp2,36mily  Rp19,7jt/bln          Syela Tjoa
# 4                5  375m²  400m²     Rp9mily  Rp75,1jt/bln      Mitha Nursanty

# %%
#Membuat file excel sebagai output
df.to_excel("bpn.xlsx",
sheet_name='rumah')

# %%
db = sqlalchemy.create_engine('postgresql://propertinext:pr0pertin3xt!@propertinext.cfnbirfqiap9.ap-southeast-1.rds.amazonaws.com:5432/propertinext')
df.to_sql('99co_rumah_jual', con=db, if_exists='replace')

print('#### data 99co sukses masuk, ({}) records processed'.format(len(df)))
# Out:
# #### data 99co sukses masuk, (259) records processed
